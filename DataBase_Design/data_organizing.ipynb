# %%
import pandas as pd
import numpy as np 
import requests
from pprint import pprint

# %%
# Load the Amazon sales report CSV file into a DataFrame
df_raw = pd.read_csv("Resources/amazon_sale_report.csv",low_memory = False);

# %%
# Remove all duplicate rows from the DataFrame, keeping only unique rows
df_cleaned = df_raw.drop_duplicates(keep=False)

# Display the first few rows of the original DataFrame to check the data
df_raw.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
# Display the names of all columns in the DataFrame
df_raw.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
# Display information about the DataFrame
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
# Identify duplicate rows in the DataFrame
duplicates = df_raw[df_raw.duplicated(keep=False)]

# Print all duplicate rows
if not duplicates.empty:  # Check if the duplicates DataFrame is not empty
    print("Duplicate rows based on all columns:")
    print(duplicates)  # Print the duplicate rows
else:
    print("No duplicates found across all columns.")  # Inform if no duplicates exist
# Out:
# No duplicates found across all columns.

# %%
# Convert the 'ship-postal-code' column to string data type
df_raw['ship-postal-code'] = df_raw['ship-postal-code'].astype(str)

# Display information about the DataFrame, including the data types of each column
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %% [markdown]
# ### above variables whether we should add sth like 0.00 etc.

# %%
# Remove any trailing '.0' from the 'ship-postal-code' column values
df_raw['ship-postal-code'] = df_raw['ship-postal-code'].str.replace(r'\.0$', '', regex=True)

# Strip whitespace from the column names
df_raw.columns = df_raw.columns.str.strip()

# Display the first few rows of the cleaned DataFrame
df_raw.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level    Style              SKU  \
# 0   Merchant     Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant     Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon     Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant     Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon     Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
# Create a new DataFrame by selecting specific columns and removing duplicates based on 'Order ID'
completed_order_df = df_raw[['Order ID','Status', 'Fulfilment','Amount']].drop_duplicates(subset=['Order ID'])

# Rename the columns for better readability and consistency
completed_order_df.columns = ['OrderID','Status', 'Fulfilment','Amount']

# Fill missing values in specified columns
completed_order_df['Amount'].fillna(0, inplace=True)

# Display the first few rows of the updated DataFrame
completed_order_df.head()
# Out:
# C:\Users\nkort\AppData\Local\Temp\ipykernel_27984\850014093.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   completed_order_df['Amount'].fillna(0, inplace=True)
#                OrderID                        Status Fulfilment  Amount
# 0  405-8078784-5731545                     Cancelled   Merchant  647.62
# 1  171-9198151-1101146  Shipped - Delivered to Buyer   Merchant  406.00
# 2  404-0687676-7273146                       Shipped     Amazon  329.00
# ...

# %%
# Display unique values in the 'Fulfilment' column
status_values = completed_order_df['Status'].unique()
print(status_values)
# Out:
# ['Cancelled' 'Shipped - Delivered to Buyer' 'Shipped'
#  'Shipped - Returned to Seller' 'Shipped - Rejected by Buyer'
#  'Shipped - Lost in Transit' 'Shipped - Out for Delivery'
#  'Shipped - Returning to Seller' 'Shipped - Picked Up' 'Pending'
#  'Pending - Waiting for Pick Up' 'Shipped - Damaged' 'Shipping']

# %%
completed_order_df.groupby('Status')['OrderID'].count()
# Out:
# Status
# Cancelled                        17185
# Pending                            584
# Pending - Waiting for Pick Up      262
# Shipped                          72826
# Shipped - Damaged                    1
# Shipped - Delivered to Buyer     26566
# Shipped - Lost in Transit            4
# Shipped - Out for Delivery          32
# Shipped - Picked Up                918
# Shipped - Rejected by Buyer         11
# Shipped - Returned to Seller      1851
# Shipped - Returning to Seller      130
# Shipping                             8
# Name: OrderID, dtype: int64

# %%
# Filter out unwanted statuses and sum the 'Amount' grouped by 'Status'
filtered_sum = completed_order_df[~completed_order_df['Status'].isin(['Cancelled', 'Pending', 'Pending - Waiting for Pick Up'])] \
    .groupby('Status')['Amount'].sum()

filtered_sum
# Out:
# Status
# Shipped                          47190704.0
# Shipped - Damaged                    1136.0
# Shipped - Delivered to Buyer     17287698.0
# Shipped - Lost in Transit            1498.0
# Shipped - Out for Delivery          23847.0
# Shipped - Picked Up                622531.0
# Shipped - Rejected by Buyer          7295.0
# Shipped - Returned to Seller      1205590.0
# Shipped - Returning to Seller       95454.0
# Shipping                                0.0
# Name: Amount, dtype: float64

# %%
# Filter out unwanted statuses and sum the 'Amount' for the remaining rows
total_sum_filtered = completed_order_df[~completed_order_df['Status'].isin(['Cancelled', 'Pending', 'Pending - Waiting for Pick Up'])]['Amount'].sum()
formatted_inr = f"₹{total_sum_filtered:,.2f}"
print(formatted_inr)
# Out:
# ₹66,435,753.00

# %%
# Define the exchange rate (assumed to be 1 USD = 84 INR)
exchange_rate = 84

# Convert the total sum from INR to USD
total_sum_usd = round(total_sum_filtered / exchange_rate,2)
formatted_usd = f"${total_sum_usd:,.2f}"
print(formatted_usd)
# Out:
# $790,901.82

# %%
# Create a new DataFrame by selecting specific columns and removing duplicates based on 'Order ID'
orders_df = df_raw[['Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel', 'ship-service-level', 'B2B']].drop_duplicates(subset=['Order ID'])

# Rename the columns for better readability and consistency
orders_df.columns = ['OrderID', 'Date', 'Status', 'Fulfilment', 'SalesChannel', 'ShipServiceLevel', 'B2B']

# Display the first few rows of the new DataFrame
orders_df.head()
# Out:
#                OrderID      Date                        Status Fulfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3  403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4  407-1069790-7240320  04-30-22                       Shipped     Amazon
#
#   SalesChannel ShipServiceLevel    B2B
# 0    Amazon.in         Standard  False
# 1    Amazon.in         Standard  False
# 2    Amazon.in        Expedited   True
# 3    Amazon.in         Standard  False
# 4    Amazon.in        Expedited  False

# %%
# Create a new DataFrame by selecting specific columns and removing duplicates based on 'Order ID' and 'SKU'
products_df = df_raw[['SKU', 'Order ID', 'Style', 'Category', 'Qty', 'currency', 'Amount']].drop_duplicates(subset=['Order ID', 'SKU'])

# Rename the columns for better readability and consistency
products_df.columns = ['SKU', 'OrderID', 'Style', 'Category', 'Qty', 'Currency', 'Amount']

# Display the first few rows of the new DataFrame
products_df.head()
# Out:
#                SKU              OrderID    Style       Category  Qty Currency  \
# 0   SET389-KR-NP-S  405-8078784-5731545   SET389            Set    0      INR
# 1  JNE3781-KR-XXXL  171-9198151-1101146  JNE3781          kurta    1      INR
# 2    JNE3371-KR-XL  404-0687676-7273146  JNE3371          kurta    1      INR
# 3       J0341-DR-L  403-9615377-8133951    J0341  Western Dress    0      INR
# 4  JNE3671-TU-XXXL  407-1069790-7240320  JNE3671            Top    1      INR
#
#    Amount
# 0  647.62
# 1  406.00
# 2  329.00
# 3  753.33
# 4  574.00

# %%
# Create a new DataFrame by selecting specific columns and removing duplicates based on 'Order ID'
shipping_df = df_raw[['Order ID', 'ship-city', 'ship-state', 'ship-postal-code', 'ship-country']].copy()

# Rename the columns for better readability and consistency
shipping_df.columns = ['OrderID', 'ShipCity', 'ShipState', 'ShipPostalCode', 'ShipCountry']
shipping_df['ShipCity'] = shipping_df['ShipCity'].str.title()
shipping_df['ShipState'] = shipping_df['ShipState'].str.title()


# Display the first few rows of the new DataFrame
shipping_df.head()
# Out:
#                OrderID     ShipCity    ShipState ShipPostalCode ShipCountry
# 0  405-8078784-5731545       Mumbai  Maharashtra         400081          IN
# 1  171-9198151-1101146    Bengaluru    Karnataka         560085          IN
# 2  404-0687676-7273146  Navi Mumbai  Maharashtra         410210          IN
# 3  403-9615377-8133951   Puducherry   Puducherry         605008          IN
# 4  407-1069790-7240320      Chennai   Tamil Nadu         600073          IN

# %% [markdown]
# ### Fixing the ShipStates columns because there are different variations and spellings for the same state value

# %%
shipping_df['ShipState'].unique()
# Out:
# array(['Maharashtra', 'Karnataka', 'Puducherry', 'Tamil Nadu',
#        'Uttar Pradesh', 'Chandigarh', 'Telangana', 'Andhra Pradesh',
#        'Rajasthan', 'Delhi', 'Haryana', 'Assam', 'Jharkhand',
#        'Chhattisgarh', 'Odisha', 'Kerala', 'Madhya Pradesh',
#        'West Bengal', 'Nagaland', 'Gujarat', 'Uttarakhand', 'Bihar',
#        'Jammu & Kashmir', 'Punjab', 'Himachal Pradesh',
#        'Arunachal Pradesh', 'Manipur', 'Goa', 'Meghalaya', 'Tripura',
#        'Ladakh', 'Dadra And Nagar', 'Sikkim', nan, 'Andaman & Nicobar ',
#        'Rajshthan', 'Nl', 'Mizoram', 'New Delhi',
#        'Punjab/Mohali/Zirakpur', 'Rj', 'Orissa', 'Lakshadweep', 'Pb',
#        'Apo', 'Ar', 'Pondicherry', 'Rajsthan'], dtype=object)

# %%
cleaned_shipping_df = shipping_df.copy()

# %%
# Step 2: Cleaned list of Indian states and union territories
cleaned_states_ut = [
    'Maharashtra', 'Karnataka', 'Puducherry', 'Tamil Nadu', 'Uttar Pradesh',
    'Chandigarh', 'Telangana', 'Andhra Pradesh', 'Rajasthan', 'Delhi',
    'Haryana', 'Assam', 'Jharkhand', 'Chhattisgarh', 'Odisha', 'Kerala',
    'Madhya Pradesh', 'West Bengal', 'Nagaland', 'Gujarat', 'Uttarakhand',
    'Bihar', 'Jammu & Kashmir', 'Punjab', 'Himachal Pradesh', 'Arunachal Pradesh',
    'Manipur', 'Goa', 'Meghalaya', 'Tripura', 'Ladakh', 'Dadra and Nagar Haveli and Daman and Diu',
    'Sikkim', 'Andaman & Nicobar Islands', 'Lakshadweep'
]

# Step 3: Define a mapping of common errors or abbreviations to correct names
state_corrections = {
    'Pondicherry': 'Puducherry',
    'Orissa': 'Odisha',
    'Rajsthan': 'Rajasthan',
    'Rajshthan': 'Rajasthan',
    'Rj': 'Rajasthan',
    'Pb': 'Punjab',
    'Nl': 'Nagaland',
    'New Delhi': 'Delhi',
    'Punjab/Mohali/Zirakpur': 'Punjab',
    'Apo': None,  # Drop these rows if it's not valid
    'Ar': 'Arunachal Pradesh',
    'Dadra And Nagar': 'Dadra and Nagar Haveli and Daman and Diu',
    # Handle missing or NaN
    None: None,  # Retain NaNs as is or drop them later
    'nan': None  # Handle missing values
}

# Step 4: Update the 'shipstate' column
# Apply the corrections map and filter by cleaned_states_ut list
cleaned_shipping_df['ShipState'] = cleaned_shipping_df['ShipState'].replace(state_corrections)

# Step 5: Ensure that only valid states/UTs are retained
# If any values in 'shipstate' are not in the cleaned_states_ut list, set them to NaN
cleaned_shipping_df['ShipState'] = cleaned_shipping_df['ShipState'].apply(lambda x: x if x in cleaned_states_ut else None)

# Step 6: Optionally, drop rows with missing or invalid states
# df = df.dropna(subset=['shipstate'])

# Step 7: Save the updated dataset
cleaned_shipping_df.head()
# Out:
#                OrderID     ShipCity    ShipState ShipPostalCode ShipCountry
# 0  405-8078784-5731545       Mumbai  Maharashtra         400081          IN
# 1  171-9198151-1101146    Bengaluru    Karnataka         560085          IN
# 2  404-0687676-7273146  Navi Mumbai  Maharashtra         410210          IN
# 3  403-9615377-8133951   Puducherry   Puducherry         605008          IN
# 4  407-1069790-7240320      Chennai   Tamil Nadu         600073          IN

# %%
cleaned_shipping_df['ShipState'].nunique()
# Out:
# 34

# %%
# Drop all null values from each DataFrame
orders_df = orders_df.dropna()
products_df = products_df.dropna()
cleaned_shipping_df = cleaned_shipping_df.dropna()
completed_order_df = completed_order_df.dropna()

# Drop duplicate OrderIDs in each DataFrame before exporting
orders_df = orders_df.drop_duplicates(subset='OrderID', keep='first')  
products_df = products_df.drop_duplicates(subset='OrderID', keep='first')  
cleaned_shipping_df = cleaned_shipping_df.drop_duplicates(subset='OrderID', keep='first')  
completed_order_df = completed_order_df.drop_duplicates(subset='OrderID', keep='first')

# Export the cleaned DataFrames to CSV
orders_df.to_csv("Data/orders_table.csv", index=False)
products_df.to_csv("Data/products_table.csv", index=False)
cleaned_shipping_df.to_csv("Data/shipping_table.csv", index=False)
completed_order_df.to_csv("Data/completed_order_table.csv", index=False)

# %%
cleaned_shipping_df.groupby('ShipState')['OrderID'].count()
# Out:
# ShipState
# Andhra Pradesh                               4979
# Arunachal Pradesh                             134
# Assam                                        1601
# Bihar                                        2017
# Chandigarh                                    315
# Chhattisgarh                                  873
# Dadra and Nagar Haveli and Daman and Diu       60
# Delhi                                        6609
# Goa                                          1081
# Gujarat                                      4169
# Haryana                                      4142
# Himachal Pradesh                              750
# Jammu & Kashmir                               670
# Jharkhand                                    1382
# Karnataka                                   16182
# Kerala                                       6105
# Ladakh                                         42
# Lakshadweep                                     4
# Madhya Pradesh                               2375
# ...

# %% [markdown]
# ### Adding Latitude/Longitude with Shipping State to create a Leaflet Visual

# %%
def get_lat_long_google(state_name, country="India", api_key=None):
    # Construct the query as State + Country to ensure you get the correct location
    location_query = f"{state_name}, {country}"
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location_query}&key={api_key}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data['results']:
            location = data['results'][0]['geometry']['location']
            return location['lat'], location['lng']
        else:
            return None, None
    else:
        return None, None

# %%
cleaned_shipping_df['ShipState'].unique()
# Out:
# array(['Maharashtra', 'Karnataka', 'Puducherry', 'Tamil Nadu',
#        'Uttar Pradesh', 'Chandigarh', 'Telangana', 'Andhra Pradesh',
#        'Rajasthan', 'Delhi', 'Haryana', 'Assam', 'Jharkhand',
#        'Chhattisgarh', 'Odisha', 'Kerala', 'Madhya Pradesh',
#        'West Bengal', 'Nagaland', 'Gujarat', 'Uttarakhand', 'Bihar',
#        'Jammu & Kashmir', 'Punjab', 'Himachal Pradesh',
#        'Arunachal Pradesh', 'Manipur', 'Goa', 'Meghalaya', 'Tripura',
#        'Ladakh', 'Dadra and Nagar Haveli and Daman and Diu', 'Sikkim',
#        'Lakshadweep'], dtype=object)

# %%
# List of Indian states
indian_states = cleaned_shipping_df['ShipState'].unique().tolist()

# Replace with your Google API key
api_key = "AIzaSyBXt_sejCaavuLglZZrD-uSeWrvfC525qY"

# Iterate through states and get their latitude and longitude
state_coordinates = {}

for state in indian_states:
    lat, lon = get_lat_long_google(state, api_key=api_key)
    state_coordinates[state] = (lat, lon)

pprint(state_coordinates)
# Out:
# {'Andhra Pradesh': (15.9128998, 79.7399875),
#  'Arunachal Pradesh': (28.2179994, 94.7277528),
#  'Assam': (26.2006043, 92.9375739),
#  'Bihar': (25.9644427, 85.2722472),
#  'Chandigarh': (30.7333148, 76.7794179),
#  'Chhattisgarh': (21.2786567, 81.8661442),
#  'Dadra and Nagar Haveli and Daman and Diu': (20.1808672, 73.0169135),
#  'Delhi': (28.7040592, 77.10249019999999),
#  'Goa': (15.2993265, 74.12399599999999),
#  'Gujarat': (22.6708317, 71.5723953),
#  'Haryana': (29.0587757, 76.085601),
#  'Himachal Pradesh': (32.1024076, 77.5619419),
#  'Jammu & Kashmir': (32.7266016, 74.8570259),
#  'Jharkhand': (23.6913486, 85.2722472),
#  'Karnataka': (15.3172775, 75.7138884),
#  'Kerala': (10.1631526, 76.64127119999999),
#  'Ladakh': (34.2268475, 77.5619419),
#  'Lakshadweep': (9.985089192440064, 72.93247324992308),
#  'Madhya Pradesh': (22.9734229, 78.6568942),
#  'Maharashtra': (19.7514798, 75.7138884),
#  'Manipur': (24.6637173, 93.90626879999999),
# ...

# %%
# Convert the dictionary into a DataFrame
states_info_df = pd.DataFrame.from_dict(state_coordinates, orient='index', columns=['Latitude', 'Longitude']).reset_index()

# Rename the index column to "State"
states_info_df = states_info_df.rename(columns={'index': 'ShipState'})

# Display the DataFrame
states_info_df
# Out:
#                                    ShipState   Latitude  Longitude
# 0                                Maharashtra  19.751480  75.713888
# 1                                  Karnataka  15.317277  75.713888
# 2                                 Puducherry  11.941685  79.808318
# 3                                 Tamil Nadu  11.127123  78.656894
# 4                              Uttar Pradesh  27.570589  80.098187
# 5                                 Chandigarh  30.733315  76.779418
# 6                                  Telangana  17.094416  79.775032
# 7                             Andhra Pradesh  15.912900  79.739987
# 8                                  Rajasthan  27.023804  74.217933
# 9                                      Delhi  28.704059  77.102490
# 10                                   Haryana  29.058776  76.085601
# 11                                     Assam  26.200604  92.937574
# 12                                 Jharkhand  23.691349  85.272247
# ...

# %%
counts_per_state = cleaned_shipping_df.groupby('ShipState')['OrderID'].count()
counts_per_state
# Out:
# ShipState
# Andhra Pradesh                               4979
# Arunachal Pradesh                             134
# Assam                                        1601
# Bihar                                        2017
# Chandigarh                                    315
# Chhattisgarh                                  873
# Dadra and Nagar Haveli and Daman and Diu       60
# Delhi                                        6609
# Goa                                          1081
# Gujarat                                      4169
# Haryana                                      4142
# Himachal Pradesh                              750
# Jammu & Kashmir                               670
# Jharkhand                                    1382
# Karnataka                                   16182
# Kerala                                       6105
# Ladakh                                         42
# Lakshadweep                                     4
# Madhya Pradesh                               2375
# ...

# %%
final_state_info_df = pd.merge(states_info_df,counts_per_state, on='ShipState')
final_state_info_df.rename(columns={'OrderID': 'Count'},inplace=True)
final_state_info_df.sort_values(by = 'Count',ascending = False)
# Out:
#                                    ShipState   Latitude  Longitude  Count
# 0                                Maharashtra  19.751480  75.713888  20780
# 1                                  Karnataka  15.317277  75.713888  16182
# 3                                 Tamil Nadu  11.127123  78.656894  10519
# 6                                  Telangana  17.094416  79.775032  10405
# 4                              Uttar Pradesh  27.570589  80.098187  10062
# 9                                      Delhi  28.704059  77.102490   6609
# 15                                    Kerala  10.163153  76.641271   6105
# 17                               West Bengal  22.986757  87.854975   5653
# 7                             Andhra Pradesh  15.912900  79.739987   4979
# 19                                   Gujarat  22.670832  71.572395   4169
# 10                                   Haryana  29.058776  76.085601   4142
# 8                                  Rajasthan  27.023804  74.217933   2512
# ...

# %%
final_state_sorted_df = final_state_info_df.sort_values(by = 'Count',ascending = False)
final_state_sorted_df['ShipState'] = final_state_sorted_df['ShipState'].str.strip()
final_state_sorted_df.reset_index(drop=True, inplace=True)
final_state_sorted_df
# Out:
#                                    ShipState   Latitude  Longitude  Count
# 0                                Maharashtra  19.751480  75.713888  20780
# 1                                  Karnataka  15.317277  75.713888  16182
# 2                                 Tamil Nadu  11.127123  78.656894  10519
# 3                                  Telangana  17.094416  79.775032  10405
# 4                              Uttar Pradesh  27.570589  80.098187  10062
# 5                                      Delhi  28.704059  77.102490   6609
# 6                                     Kerala  10.163153  76.641271   6105
# 7                                West Bengal  22.986757  87.854975   5653
# 8                             Andhra Pradesh  15.912900  79.739987   4979
# 9                                    Gujarat  22.670832  71.572395   4169
# 10                                   Haryana  29.058776  76.085601   4142
# 11                                 Rajasthan  27.023804  74.217933   2512
# ...

# %%
final_state_sorted_df.to_csv("C:\\Users\\nkort\\UCI DA Class Folder\\Homework\\Project-3---Data-Engineering-and-Visualization\\Visual_Data\\state_order_counts.csv",index = False)
